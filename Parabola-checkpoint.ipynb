# %%
from pyglet.gl import *
from pyglet import app
from pyglet.window import Window, key
d = 10
wx, wy = 1.5 * d, 1.1 * d # Параметры области визуализации
width, height = int(20 * wx), int(20 * wy) # Размеры окна вывода
texFromFile = True # True False
tile_x = 2 # Число повторов текстуры по X
tile_y = 2 # Число повторов текстуры по Y
def to_c_float_Array(data): # Преобразование в си-массив
    return (GLfloat * len(data))(*data)
#vld = to_c_float_Array([-d, -d, 0]) # Левая нижняя вершина
#vrd = to_c_float_Array([d, -d, 0]) # Правая нижняя вершина
#vru = to_c_float_Array([d, d, 0]) # Правая верхняя вершина
#vlu = to_c_float_Array([-d, d, 0]) # Левая верхняя вершина
#
def texInit():
    if texFromFile:
        fn = 'C:\\Users\\User\\opm_t3_gl25_16-17.jpg'
        img = pyglet.image.load(fn)
        iWidth = img.width
        iHeight = img.height
        img = img.get_data('RGB', iWidth * 3)
    else:
        iWidth = iHeight = 64 # Размер текстуры равен iWidth * iHeight
        n = 3 * iWidth * iHeight
        # Каждый элемент текстуры содержит три компонента (формат текстуры GL_RGB)
        # GL_UNSIGNED_BYTE - это диапазон 0-255, поэтому для img задается GLuint
        img = np.zeros((3, iWidth, iHeight), dtype = 'uint8')
        for i in range(iHeight): # Генерация черно-белого образа, на основе которого создается текстура
            for j in range(iWidth):
                img[:, i, j] = ((i - 1) & 16 ^ (j - 1) & 16) * 255
        img = img.reshape(n)
        img = (GLubyte * n)(*img)
    p = GL_TEXTURE_2D
    r = GL_RGB
    # Задаем параметры текстуры
    glTexParameterf(p, GL_TEXTURE_WRAP_S, GL_REPEAT) # GL_CLAMP
    glTexParameterf(p, GL_TEXTURE_WRAP_T, GL_REPEAT)
    glTexParameterf(p, GL_TEXTURE_MAG_FILTER, GL_LINEAR)
    glTexParameterf(p, GL_TEXTURE_MIN_FILTER, GL_LINEAR)
    # Способ взаимодействия с текущим фрагментом изображения
    glTexEnvf(GL_TEXTURE_ENV, GL_TEXTURE_ENV_MODE, GL_DECAL)
    # Создаем 2d-текстуру на основе образа img
    glTexImage2D(p, 0, r, iWidth, iHeight, 0, r, GL_UNSIGNED_BYTE, img)
    glEnable(p)
window = Window(visible = True, width = width, height = height,
                resizable = True, caption = 'Текстура')
glClearColor(0.1, 0.1, 0.1, 1.0)
glClear(GL_COLOR_BUFFER_BIT)
texInit()
angle = 0
@window.event
def on_draw():
    window.clear()
    glMatrixMode(GL_PROJECTION)
    glLoadIdentity()
    glOrtho(-wx, wx, -wy, wy, -10, 10)
    gl.glRotatef(angle, 0, 1, 0)
    
    gl.glBegin(gl.GL_QUAD_STRIP)
    glTexCoord2f(0, 0)
    gl.glVertex3f(0, -3, -4)
    glTexCoord2f(tile_x, 0)
    gl.glVertex3f(0, 7, -4)
    glTexCoord2f(tile_x, tile_y)
    gl.glVertex3f(4, 0, 0)
    glTexCoord2f(0, tile_y)
    gl.glVertex3f(4, 10, 0)
    glTexCoord2f(0, 0)
    gl.glVertex3f(9, 0, -3)
    glTexCoord2f(tile_x, 0)
    gl.glVertex3f(9, 10, -3)
    glTexCoord2f(tile_x, tile_y)
    gl.glVertex3f(9, 0, -8)
    glTexCoord2f(0, tile_y)
    gl.glVertex3f(9, 10, -8)
    glTexCoord2f(0, 0)
    gl.glVertex3f(0, -3, -4)
    glTexCoord2f(tile_x, 0)
    gl.glVertex3f(0, 7, -4)
    gl.glEnd()
    
    gl.glBegin(gl.GL_QUADS)
    glTexCoord2f(0, 0)
    gl.glVertex3f(0, -3, -4)
    glTexCoord2f(tile_x, 0)
    gl.glVertex3f(4, 0, 0)
    glTexCoord2f(tile_x, tile_y)
    gl.glVertex3f(9, 0, -3)
    glTexCoord2f(0, tile_y)
    gl.glVertex3f(9, 0, -8)
    glTexCoord2f(0, 0)
    gl.glVertex3f(0, 7, -4)
    glTexCoord2f(0, tile_y)
    gl.glVertex3f(4, 10, 0)
    glTexCoord2f(tile_x, tile_y)
    gl.glVertex3f(9, 10, -3)
    glTexCoord2f(tile_x, 0)
    gl.glVertex3f(9, 10, -8)
    gl.glEnd()
    
    
@window.event
def on_key_press(symbol, modifiers):
    global tile_x, tile_y, angle
    if symbol == key._1:
        tile_x =1
        tile_y = 1
    elif symbol == key._2:
        tile_x =2
        tile_y = 2
    elif symbol == key._3:
        tile_x =3
        tile_y = 2
    elif symbol == key._4:
        angle +=5
app.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pyglet\__init__.py in __getattr__(self, name)
#     377         try:
# --> 378             return getattr(self._module, name)
#     379         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'get_default'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12104/2999132740.py in <module>
# ----> 1 from pyglet.gl import *
#       2 from pyglet import app
#       3 from pyglet.window import Window, key
#       4 d = 10
#       5 wx, wy = 1.5 * d, 1.1 * d # Параметры области визуализации
#
# ~\anaconda3\lib\site-packages\pyglet\gl\__init__.py in <module>
#     237     # trickery is for circular import
#     238     _pyglet.gl = _sys.modules[__name__]
# --> 239     import pyglet.window
#
# ~\anaconda3\lib\site-packages\pyglet\window\__init__.py in <module>
#    1894 if not _is_pyglet_docgen:
#    1895     pyglet.window = sys.modules[__name__]
# -> 1896     gl._create_shadow_window()
#    1897
#
# ~\anaconda3\lib\site-packages\pyglet\gl\__init__.py in _create_shadow_window()
#     206
#     207     from pyglet.window import Window
# --> 208     _shadow_window = Window(width=1, height=1, visible=False)
#     209     _shadow_window.switch_to()
#     210
#
# ~\anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in __init__(self, *args, **kwargs)
#     132
#     133
# --> 134         super(Win32Window, self).__init__(*args, **kwargs)
#     135
#     136     def _recreate(self, changes):
#
# ~\anaconda3\lib\site-packages\pyglet\window\__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     499
#     500         if not display:
# --> 501             display = get_platform().get_default_display()
#     502
#     503         if not screen:
#
# ~\anaconda3\lib\site-packages\pyglet\window\__init__.py in get_default_display(self)
#    1843         :rtype: `Display`
#    1844         """
# -> 1845         return pyglet.canvas.get_display()
#    1846
#    1847 if _is_pyglet_docgen:
#
# ~\anaconda3\lib\site-packages\pyglet\canvas\__init__.py in get_display()
#      75     # If there's an existing display, return it (return arbitrary display if
#      76     # there are multiple).
# ---> 77     from pyglet.app import displays
#      78     for display in displays:
#      79         return display
#
# ~\anaconda3\lib\site-packages\pyglet\app\__init__.py in <module>
#     173 #: with their own subclass of :class:`EventLoop` before calling
#     174 #: :meth:`EventLoop.run`.
# --> 175 event_loop = EventLoop()
#     176
#     177 platform_event_loop = PlatformEventLoop()
#
# ~\anaconda3\lib\site-packages\pyglet\app\base.py in __init__(self)
#     117     def __init__(self):
#     118         self._has_exit_condition = threading.Condition()
# --> 119         self.clock = clock.get_default()
#     120         self.is_running = False
#     121
#
# ~\anaconda3\lib\site-packages\pyglet\__init__.py in __getattr__(self, name)
#     382
#     383             import_name = 'pyglet.%s' % self._module_name
# --> 384             __import__(import_name)
#     385             module = sys.modules[import_name]
#     386             object.__setattr__(self, '_module', module)
#
# ~\anaconda3\lib\site-packages\pyglet\clock.py in <module>
#     164             time.sleep(microseconds * 1e-6)
#     165
# --> 166     _default_time_function = time.clock
#     167
#     168 else:
#
# AttributeError: module 'time' has no attribute 'clock'
