# %%
import numpy as np
import matplotlib.pyplot as plt
import pyglet
from pyglet.gl import *
from pyglet import graphics
from pyglet import app
from pyglet.window import Window, key
import random as r

# %%
p = np.sqrt(5)/2
vd20 = [[0, 1, p], [1, p, 0], [-1, p, 0], 
        [0, 1, -p], [-p, 0, -1], [0, -1, -p], 
        [-1, -p, 0], [1, -p, 0], [0, -1, p], 
        [p, 0, 1], [p, 0, -1], [-p, 0, 1]]

for i in range(0,12):
    for j in range (0, 3):
        vd20[i][j]*=7
vd20
# Out:
# [[0, 7, 7.826237921249264],
#  [7, 7.826237921249264, 0],
#  [-7, 7.826237921249264, 0],
#  [0, 7, -7.826237921249264],
#  [-7.826237921249264, 0, -7],
#  [0, -7, -7.826237921249264],
#  [-7, -7.826237921249264, 0],
#  [7, -7.826237921249264, 0],
#  [0, -7, 7.826237921249264],
#  [7.826237921249264, 0, 7],
#  [7.826237921249264, 0, -7],
#  [-7.826237921249264, 0, 7]]

# %%
d = 10
wx, wy = 1.5 * d, 1.1 * d # Параметры области визуализации
width, height = int(20 * wx), int(20 * wy) # Размеры окна вывода
window = Window(visible = True, width = width, height = height,
                resizable = True, caption = 'Кость')
glClearColor(0.1, 0.1, 0.1, 1.0)
glClear(GL_COLOR_BUFFER_BIT)
angle = [0, 0, 0]
gl.glShadeModel(gl.GL_FLAT)
@window.event
def on_draw():
    window.clear()
    glMatrixMode(GL_PROJECTION)
    glLoadIdentity()
    glOrtho(-wx, wx, -wy, wy, -10, 10)
    gl.glLineWidth(4)
    gl.glPointSize(16)    
    gl.glRotatef(angle[0], 1, 0, 0)
    gl.glRotatef(angle[1], 0, 1, 0)
    gl.glRotatef(angle[2], 0, 0, 1)
    gl.glPolygonMode(gl.GL_FRONT, gl.GL_LINE)
    gl.glPolygonMode(gl.GL_BACK, gl.GL_LINE)

    graphics.draw(11, GL_TRIANGLE_STRIP, ('v3f', (vd20[0][0], vd20[0][1], vd20[0][2],                                                   vd20[1][0], vd20[1][1], vd20[1][2], 
                                                  vd20[2][0], vd20[2][1], vd20[2][2], 
                                                  vd20[3][0], vd20[3][1], vd20[3][2], 
                                                  vd20[4][0], vd20[4][1], vd20[4][2], 
                                                  vd20[5][0], vd20[5][1], vd20[5][2],  
                                                  vd20[6][0], vd20[6][1], vd20[6][2],  
                                                  vd20[7][0], vd20[7][1], vd20[7][2],  
                                                  vd20[8][0], vd20[8][1], vd20[8][2],  
                                                  vd20[9][0], vd20[9][1], vd20[9][2],  
                                               #   vd20[10][0], vd20[10][1], vd20[10][2],  
                                               #   vd20[11][0], vd20[11][1], vd20[11][2], 
                                                 vd20[0][0], vd20[0][1], vd20[0][2])), 
                 ('c3f', ((int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                      #   (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                     #    (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2))))
    graphics.draw(7, GL_TRIANGLE_FAN, ('v3f', (vd20[11][0], vd20[11][1], vd20[11][2],
                                              vd20[0][0], vd20[0][1], vd20[0][2],
                                              vd20[8][0], vd20[8][1], vd20[8][2],
                                              vd20[6][0], vd20[6][1], vd20[6][2],
                                              vd20[4][0], vd20[4][1], vd20[4][2],
                                              vd20[2][0], vd20[2][1], vd20[2][2],
                                              vd20[0][0], vd20[0][1], vd20[0][2])), ('c3f', ((int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2),
                        (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2))))
    
    graphics.draw(7, GL_TRIANGLE_FAN, ('v3f', (vd20[10][0], vd20[10][1], vd20[10][2],
                                              vd20[7][0], vd20[7][1], vd20[7][2],
                                              vd20[9][0], vd20[9][1], vd20[9][2],
                                              vd20[1][0], vd20[1][1], vd20[1][2],
                                              vd20[3][0], vd20[3][1], vd20[3][2],
                                              vd20[5][0], vd20[5][1], vd20[5][2],
                                              vd20[7][0], vd20[7][1], vd20[7][2])), ('c3f', ((int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2), 
                         (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2),
                        (int)(r.random()*2), (int)(r.random()*2), (int)(r.random()*2))))
    
@window.event
def on_key_press(symbol, modifiers):
    global tile_x, tile_y, angle
    if symbol == key._4:
        angle[0] +=5
    elif symbol == key._5:
        angle[1] +=5
    elif symbol == key._6:
        angle[2] +=5
app.run()
